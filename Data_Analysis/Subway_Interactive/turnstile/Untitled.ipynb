# %%
import pandas as pd
from pprintpp import pprint as pp
import numpy as np 
import altair as alt
from vega_datasets import data
import random
pd.set_option('display.max_rows', 500)

# %%
mar20 = pd.read_csv('turnstile_mar2020.csv')
mar21 = pd.read_csv('turnstile_mar2021.csv')

# %%
len(mar20)
# Out:
# 207017

# %%
mar21 = mar21[(mar21['change'] < 10000) & (mar21['change'] > 0 ) ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1048570
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-f3910b0939c2> in <module>
# ...

# %%
mar21.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION     DATE      TIME     DESC  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  2/20/21   3:00:00  REGULAR
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  2/20/21   7:00:00  REGULAR
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  2/20/21  11:00:00  REGULAR
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  2/20/21  15:00:00  REGULAR
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  2/20/21  19:00:00  REGULAR
#
#    ENTRIES  \
# 0  7533822
# 1  7533826
# 2  7533854
# 3  7533940
# 4  7534089
#
#    EXITS                                                                 \
# 0                                            2568869
# 1                                            2568881
# 2                                            2568925
# 3                                            2568965
# 4                                            2568994
#
#    change
# 0       0
# 1       4
# 2      28
# 3      86
# 4     149

# %%
mar21 = mar21[(mar21['change'] < 10000) & (mar21['change'] > 0 ) ]

# %%
mar21
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION     DATE  \
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  2/20/21
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  2/20/21
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  2/20/21
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  2/20/21
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT  2/20/21
# ...       ...   ...       ...            ...      ...      ...      ...
# 209755  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  2/26/21
# 209756  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  2/26/21
# 209757  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  2/26/21
# 209758  TRAM2  R469  00-00-01  RIT-ROOSEVELT        R      RIT  2/26/21
# 209885  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  2/20/21
#
#             TIME     DESC  ENTRIES  \
# 1        7:00:00  REGULAR  7533826
# ...

# %%
mar21_week = mar21.groupby(['STATION']).sum().reset_index()
