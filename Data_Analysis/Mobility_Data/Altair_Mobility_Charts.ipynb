# %%
import pandas as pd
from pprintpp import pprint as pp
import numpy as np 
import altair as alt
from vega_datasets import data
import random
import glob
# Out:
# /Users/shaneburke/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
mobility = pd.read_csv("mobility_data_for_altair.csv")

# %%
mobility
# Out:
#          Date           Area Mode of Transportation  Difference
# 0     1/26/20  New York City                Driving  104.379286
# 1     1/27/20  New York City                Driving  103.981429
# 2     1/28/20  New York City                Driving  103.692857
# 3     1/29/20  New York City                Driving  103.327143
# 4     1/30/20  New York City                Driving  102.938571
# ...       ...            ...                    ...         ...
# 8581  5/12/21  Staten Island                Walking  135.460714
# 8582  5/13/21  Staten Island                Walking  137.197143
# 8583  5/14/21  Staten Island                Walking  138.223571
# 8584  5/15/21  Staten Island                Walking  139.159286
# 8585  5/16/21  Staten Island                Walking  139.426429
#
# [8586 rows x 4 columns]

# %%
mobility['Date'] = pd.to_datetime(mobility.Date)

# %%
mobility['Difference'] =  mobility['Difference'] / 100

# %%
mobility['Change compared to baseline'] = mobility['Difference'] - 1

# %%
nyc = mobility[mobility['Area'] == "New York City"]
mn = mobility[mobility['Area'] == "Manhattan"]
bk = mobility[mobility['Area'] == "Brooklyn"]
bx = mobility[mobility['Area'] == "Bronx"]
qns = mobility[mobility['Area'] == "Queens"]
si = mobility[mobility['Area'] == "Staten Island"]

# %%
import altair as alt

source = nyc

chart = alt.Chart(source).mark_line().encode(
    x=alt.X('Date', title="Month"),
    y=alt.Y('Change compared to baseline', axis=alt.Axis(format='%'), scale=alt.Scale(domain=(-1, 1))),
    color='Mode of Transportation'
).properties(
    title='New York City, Total'
)

chart.configure_title(
    fontSize=20,
    font='Helvetica',
    anchor='middle',
    color='black'
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

source = bx

chart = alt.Chart(source).mark_line().encode(
    x=alt.X('Date', title="Month"),
    y=alt.Y('Change compared to baseline', axis=alt.Axis(format='%'), scale=alt.Scale(domain=(-1, 1))),
    color='Mode of Transportation'
).properties(
    title='The Bronx'
)

chart.configure_title(
    fontSize=20,
    font='Helvetica',
    anchor='middle',
    color='black'
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

source = bk

chart = alt.Chart(source).mark_line().encode(
    x=alt.X('Date', title="Month"),
    y=alt.Y('Change compared to baseline', axis=alt.Axis(format='%'), scale=alt.Scale(domain=(-1, 1))),
    color='Mode of Transportation'
).properties(
    title='Brooklyn'
)

chart.configure_title(
    fontSize=20,
    font='Helvetica',
    anchor='middle',
    color='black'
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

source = mn

chart = alt.Chart(source).mark_line().encode(
    x=alt.X('Date', title="Month"),
    y=alt.Y('Change compared to baseline', axis=alt.Axis(format='%'), scale=alt.Scale(domain=(-1, 1))),
    color='Mode of Transportation'
).properties(
    title='Manhattan'
)

chart.configure_title(
    fontSize=20,
    font='Helvetica',
    anchor='middle',
    color='black'
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

source = si

chart = alt.Chart(source).mark_line().encode(
    x=alt.X('Date', title="Month"),
    y=alt.Y('Change compared to baseline', axis=alt.Axis(format='%'), scale=alt.Scale(domain=(-1, 1))),
    color='Mode of Transportation'
).properties(
    title='Staten Island'
)

chart.configure_title(
    fontSize=20,
    font='Helvetica',
    anchor='middle',
    color='black'
)
# Out:
# alt.Chart(...)

# %%
data.stocks()
# Out:
#     symbol       date   price
# 0     MSFT 2000-01-01   39.81
# 1     MSFT 2000-02-01   36.35
# 2     MSFT 2000-03-01   43.22
# 3     MSFT 2000-04-01   28.37
# 4     MSFT 2000-05-01   25.45
# ..     ...        ...     ...
# 555   AAPL 2009-11-01  199.91
# 556   AAPL 2009-12-01  210.73
# 557   AAPL 2010-01-01  192.06
# 558   AAPL 2010-02-01  204.62
# 559   AAPL 2010-03-01  223.02
#
# [560 rows x 3 columns]
